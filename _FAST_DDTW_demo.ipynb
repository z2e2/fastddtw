# %%
from _ddtw import *
from _fastddtw import *

# %% [markdown]
# ## test case 1: alignment effect

# %%
signal_1 = np.array([71, 73, 75, 80, 80, 80, 78, 76, 75, 73, 71, 71, 71, 73, 75, 76, 76, 68, 76, 76, 75, 73, 71, 70, 70, 69, 68, 68, 72, 74, 78, 79, 80, 80, 78])
signal_2 = 0.8 * np.array([69, 69, 73, 75, 79, 80, 79, 78, 76, 73, 72, 71, 70, 70, 69, 69, 69, 71, 73, 75, 76, 76, 76, 76, 76, 75, 73, 71, 70, 70, 71, 73, 75, 80, 80, 80, 78,])

# %%
# plot raw signal
plot_raw_signals(signal_1, signal_2)

# %%
# fast ddtw
distance, path = fast_ddtw(signal_1, signal_2, K = 10)

# %%
distance
# Out:
# 28.299999999999997

# %%
path
# Out:
# [(0, 0),
#  (1, 1),
#  (1, 2),
#  (2, 3),
#  (3, 4),
#  (4, 5),
#  (4, 6),
#  (5, 7),
#  (6, 7),
#  (7, 7),
#  (8, 8),
#  (9, 9),
#  (9, 10),
#  (10, 11),
#  (10, 12),
#  (10, 13),
#  (10, 14),
#  (11, 15),
#  (12, 16),
#  (13, 17),
#  (13, 18),
#  (14, 19),
#  (15, 20),
#  (16, 21),
#  (17, 22),
#  (18, 23),
#  (19, 24),
#  (20, 25),
#  (21, 26),
#  (22, 27),
#  (23, 27),
#  (24, 27),
#  (25, 27),
#  (26, 28),
#  (26, 29),
#  (26, 30),
#  (27, 31),
#  (28, 31),
#  (29, 32),
#  (30, 33),
#  (31, 33),
#  (32, 34)]

# %%
plot_actual_search_space(signal_1, signal_2, K = 10)

# %%
# plot path
plot_alignment_path(path, title = 'alignment_path')

# %%
plot_path_in_search_space(signal_1, signal_2, path, K = 10)

# %%
# plot aligned signal
plot_aligned_signals(signal_1, signal_2, path, title = 'aligned_signals')

# %% [markdown]
# ## test case 2: run time
# * Complexity: $O(n)$

# %%
from time import time

# %%
signal_3 = np.repeat(signal_1, 21)
signal_4 = np.repeat(signal_2, 20)

# %%
# plot raw signal
plot_raw_signals(signal_3, signal_4)

# %%
# fast ddtw
start = time()
distance, path = fast_ddtw(signal_3, signal_4, K = 100)
end = time()
runtime_fastddtw = end - start
print('runtime:',  runtime_fastddtw)
print('distance:', distance)
# Out:
# runtime: 1.000776767730713
# distance: 35.59999999999998

# %%
plot_actual_search_space(signal_3, signal_4, K = 100)

# %%
# plot path
plot_alignment_path(path, title = 'alignment_path')

# %%
plot_path_in_search_space(signal_3, signal_4, path, K = 100)

# %%
# plot aligned signal
plot_aligned_signals(signal_3, signal_4, path, title = 'aligned_signals')

# %% [markdown]
# ## runtime for slow DDTW:
# * Complexity: $O(n^2)$

# %%
from _ddtw import *
start = time()
ddtw, traceback = DDTW(signal_3, signal_4)
end = time()
end = time()
runtime_slowddtw= end - start
print('runtime:',  runtime_slowddtw)
print('distance:', ddtw[-1,-1])
# Out:
# runtime: 20.283677577972412
# distance: 35.59999999999998

# %%
x, y = plot_traceback(ddtw, traceback)

# %%
new_x, new_y = plot_aligned_sig(signal_3, signal_4, x, y)

# %%
5*100*50/3600
# Out:
# 6.944444444444445

# %%
0.38*100*50/3600
# Out:
# 0.5277777777777778
